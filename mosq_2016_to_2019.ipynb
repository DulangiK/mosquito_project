# %%
import numpy as np 
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization

# %%
from google.colab import files
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc137a7c-2f59-41f3-95f5-1f46dc8cc9b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc137a7c-2f59-41f3-95f5-1f46dc8cc9b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mosquitoes_2016.csv to mosquitoes_2016.csv

# %% [markdown]
# # 2016

# %%
df = pd.read_csv('m2016.csv')
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)
# 0      5/1/2016               254.4       0.0       18.8      12.2      26.0
# 1      5/2/2016               273.5      16.5       21.1      16.5      28.4
# 2      5/3/2016               304.0      27.0       12.9       8.9      17.6
# 3      5/4/2016               256.2       0.0       15.7      10.2      20.6
# 4      5/5/2016               243.8       7.5       18.9      10.2      26.9
# ..          ...                 ...       ...        ...       ...       ...
# 237  12/27/2016                 3.3       0.5       -2.3      -6.3       1.3
# 238  12/28/2016                 2.2       0.0       -3.7      -8.4       2.6
# 239  12/29/2016                 1.4       0.3       -4.2      -7.2      -1.1
# 240  12/30/2016                 1.0       0.0       -3.9      -9.1       1.0
# 241  12/31/2016                 0.9       0.0        0.7      -3.6       5.7
#
# [242 rows x 6 columns]

# %%
df['month_year'] = pd.to_datetime(df['date']).dt.to_period('M')
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  5/1/2016               254.4       0.0       18.8      12.2      26.0
# 1  5/2/2016               273.5      16.5       21.1      16.5      28.4
# 2  5/3/2016               304.0      27.0       12.9       8.9      17.6
# 3  5/4/2016               256.2       0.0       15.7      10.2      20.6
# 4  5/5/2016               243.8       7.5       18.9      10.2      26.9
#
#   month_year
# 0    2016-05
# 1    2016-05
# 2    2016-05
# 3    2016-05
# 4    2016-05

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  5/1/2016               254.4       0.0       18.8      12.2      26.0
# 1  5/2/2016               273.5      16.5       21.1      16.5      28.4
# 2  5/3/2016               304.0      27.0       12.9       8.9      17.6
# 3  5/4/2016               256.2       0.0       15.7      10.2      20.6
# 4  5/5/2016               243.8       7.5       18.9      10.2      26.9
#
#   month_year  month
# 0    2016-05      5
# 1    2016-05      5
# 2    2016-05      5
# 3    2016-05      5
# 4    2016-05      5

# %%
df['month_name'] = 'other'
df.loc[df['month'] == 1, 'month_name'] = 'Jan'
df.loc[df['month'] == 2, 'month_name'] = 'Feb'
df.loc[df['month'] == 3, 'month_name'] = 'March'
df.loc[df['month'] == 4, 'month_name'] = 'April'
df.loc[df['month'] == 5, 'month_name'] = 'May'
df.loc[df['month'] == 6, 'month_name'] = 'June'
df.loc[df['month'] == 7, 'month_name'] = 'July'
df.loc[df['month'] == 8, 'month_name'] = 'August'
df.loc[df['month'] == 9, 'month_name'] = 'Sept'
df.loc[df['month'] == 10, 'month_name'] = 'Oct'
df.loc[df['month'] == 11, 'month_name'] = 'Nov'
df.loc[df['month'] == 12, 'month_name'] = 'Dec'

# %%
#2016

df.plot(x='date', y='mosquito_Indicator' ,visible=True)
plt.xlabel('month')
plt.show()

# %%
import matplotlib.ticker as ticker

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mosquito_Indicator', data=df)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)

#g.set_title('Mosquito distribution along the year of 2017')
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('rain(mm)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)


plt.savefig('m2016_mosq.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='rain(mm)', data=df)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)
#g.set(xlabel='months', ylabel='rain(mm)')

#g.set_title('Mosquito distribution along the year of 2017')
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('rain(mm)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)



plt.savefig('m2016_rain.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mean_T(℃)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mean_T(℃)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2016_temp.png')

# %%
df2=df

# %%
from scipy.stats import pearsonr

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.762

# %%
corr, _ = pearsonr(df['rain(mm)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.077

# %%
from scipy.stats import spearmanr

# %%
corr, _ = spearmanr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.675

# %%
corr, _ = spearmanr(df['rain(mm)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: -0.013

# %%
plt.scatter(df['rain(mm)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("rain(mm)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("rain_variation_mosquito2016.png")

# %%
plt.scatter(df['mean_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("mean_T(℃)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("temp_variation_mosquito2016.png")

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x="month_name", y="mean_T(℃)", 
            order=['May','June','July','August','Sept','Oct','Nov','Dec'],
            data=df)
plt.ylabel("mean_T(℃)", size=20)
plt.xlabel("Month", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
#plt.title("StackOverflow Survey Data", size=18)
plt.savefig("temp_2016_variation_monthly_boxplot.png")

# %% [markdown]
# # 2017

# %%
 uploaded = files.upload()
# Out:
#      <input type="file" id="files-2463a357-3f6a-4b68-8751-741b66b333ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2463a357-3f6a-4b68-8751-741b66b333ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mosquitoes_2017.csv to mosquitoes_2017.csv

# %%
df = pd.read_csv('m2017.csv')
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)
# 0      1/1/2017                 1.0       0.0        2.7      -1.6       6.9
# 1      1/2/2017                 1.1       0.3        5.0       1.8       9.2
# 2      1/3/2017                 1.2       0.0        2.0      -2.3       7.7
# 3      1/4/2017                 1.5       0.0        3.9       1.0       8.9
# 4      1/5/2017                 2.1       0.0        3.8      -0.1       7.3
# ..          ...                 ...       ...        ...       ...       ...
# 356  12/27/2017                 5.5       0.0       -6.9     -10.3      -2.6
# 357  12/28/2017                 5.5       0.0       -2.1      -6.8       0.8
# 358  12/29/2017                 5.5       0.0        2.1      -0.4       6.0
# 359  12/30/2017                 5.5       0.7        1.4      -1.2       4.5
# 360  12/31/2017                 5.5       1.0       -0.3      -3.2       3.3
#
# [361 rows x 6 columns]

# %%
df['month_year'] = pd.to_datetime(df['date']).dt.to_period('M')
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2017                 1.0       0.0        2.7      -1.6       6.9
# 1  1/2/2017                 1.1       0.3        5.0       1.8       9.2
# 2  1/3/2017                 1.2       0.0        2.0      -2.3       7.7
# 3  1/4/2017                 1.5       0.0        3.9       1.0       8.9
# 4  1/5/2017                 2.1       0.0        3.8      -0.1       7.3
#
#   month_year
# 0    2017-01
# 1    2017-01
# 2    2017-01
# 3    2017-01
# 4    2017-01

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2017                 1.0       0.0        2.7      -1.6       6.9
# 1  1/2/2017                 1.1       0.3        5.0       1.8       9.2
# 2  1/3/2017                 1.2       0.0        2.0      -2.3       7.7
# 3  1/4/2017                 1.5       0.0        3.9       1.0       8.9
# 4  1/5/2017                 2.1       0.0        3.8      -0.1       7.3
#
#   month_year  month
# 0    2017-01      1
# 1    2017-01      1
# 2    2017-01      1
# 3    2017-01      1
# 4    2017-01      1

# %%
df['month_name'] = 'other'
df.loc[df['month'] == 1, 'month_name'] = 'Jan'
df.loc[df['month'] == 2, 'month_name'] = 'Feb'
df.loc[df['month'] == 3, 'month_name'] = 'March'
df.loc[df['month'] == 4, 'month_name'] = 'April'
df.loc[df['month'] == 5, 'month_name'] = 'May'
df.loc[df['month'] == 6, 'month_name'] = 'June'
df.loc[df['month'] == 7, 'month_name'] = 'July'
df.loc[df['month'] == 8, 'month_name'] = 'August'
df.loc[df['month'] == 9, 'month_name'] = 'Sept'
df.loc[df['month'] == 10, 'month_name'] = 'Oct'
df.loc[df['month'] == 11, 'month_name'] = 'Nov'
df.loc[df['month'] == 12, 'month_name'] = 'Dec'

# %%
#2017
df.plot(x='month_name', y='mosquito_Indicator', figsize=(10,5), grid=True)

# %%
#2017
df.plot(x='month_name', y='rain(mm)', figsize=(10,5), grid=True)

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mosquito_Indicator', data=df)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set_title('Mosquito distribution along the year of 2017')
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mosquito_Indicator', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)


plt.savefig('m2017_mosq.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='rain(mm)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('rain(mm)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2017_rain.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mean_T(℃)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mean_T(℃)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2017_temp.png')

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.769

# %%
corr, _ = pearsonr(df['rain(mm)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.279

# %%
corr, _ = spearmanr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.910

# %%
corr, _ = spearmanr(df['rain(mm)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.188

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x="month_name", y="mean_T(℃)", 
            order=['Jan', 'Feb', 'March','April','May','June','July','August','Sept','Oct','Nov','Dec'],
            data=df)
plt.ylabel("mean_T(℃)", size=20)
plt.xlabel("Month", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
#plt.title("StackOverflow Survey Data", size=18)
plt.savefig("temp_2017_variation_monthly_boxplot.png")

# %%
plt.scatter(df['rain(mm)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("rain(mm)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("rain_variation_mosquito2017.png")

# %%
plt.scatter(df['mean_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("mean_T(℃)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("temp_variation_mosquito2017.png")

# %% [markdown]
# # 2018

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bd99c69-0e30-4475-988c-f1b861e2e52e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bd99c69-0e30-4475-988c-f1b861e2e52e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mosquitoes_2018.csv to mosquitoes_2018.csv

# %%
df = pd.read_csv('m2018.csv')
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)
# 0      1/1/2018                 5.5       0.0       -1.3      -5.1       3.8
# 1      1/2/2018                 5.5       0.0       -1.8      -4.3       1.8
# 2      1/3/2018                 5.5       0.0       -4.7      -7.1      -0.4
# 3      1/4/2018                 5.5       0.0       -4.7      -8.7      -0.7
# 4      1/5/2018                 5.5       0.0       -3.0      -5.6       1.6
# ..          ...                 ...       ...        ...       ...       ...
# 329  12/27/2018                 5.5       0.0      -10.1     -12.5      -6.5
# 330  12/28/2018                 5.5       0.0      -10.5     -14.4      -6.6
# 331  12/29/2018                 5.5       0.0       -7.6     -10.5      -3.0
# 332  12/30/2018                 5.5       0.0       -6.8     -11.3      -0.9
# 333  12/31/2018                 5.5       0.0       -5.4     -10.5      -0.5
#
# [334 rows x 6 columns]

# %%
df['month_year'] = pd.to_datetime(df['date']).dt.to_period('M')
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2018                 5.5       0.0       -1.3      -5.1       3.8
# 1  1/2/2018                 5.5       0.0       -1.8      -4.3       1.8
# 2  1/3/2018                 5.5       0.0       -4.7      -7.1      -0.4
# 3  1/4/2018                 5.5       0.0       -4.7      -8.7      -0.7
# 4  1/5/2018                 5.5       0.0       -3.0      -5.6       1.6
#
#   month_year
# 0    2018-01
# 1    2018-01
# 2    2018-01
# 3    2018-01
# 4    2018-01

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2018                 5.5       0.0       -1.3      -5.1       3.8
# 1  1/2/2018                 5.5       0.0       -1.8      -4.3       1.8
# 2  1/3/2018                 5.5       0.0       -4.7      -7.1      -0.4
# 3  1/4/2018                 5.5       0.0       -4.7      -8.7      -0.7
# 4  1/5/2018                 5.5       0.0       -3.0      -5.6       1.6
#
#   month_year  month
# 0    2018-01      1
# 1    2018-01      1
# 2    2018-01      1
# 3    2018-01      1
# 4    2018-01      1

# %%
df['month_name'] = 'other'
df.loc[df['month'] == 1, 'month_name'] = 'Jan'
df.loc[df['month'] == 2, 'month_name'] = 'Feb'
df.loc[df['month'] == 3, 'month_name'] = 'March'
df.loc[df['month'] == 4, 'month_name'] = 'April'
df.loc[df['month'] == 5, 'month_name'] = 'May'
df.loc[df['month'] == 6, 'month_name'] = 'June'
df.loc[df['month'] == 7, 'month_name'] = 'July'
df.loc[df['month'] == 8, 'month_name'] = 'August'
df.loc[df['month'] == 9, 'month_name'] = 'Sept'
df.loc[df['month'] == 10, 'month_name'] = 'Oct'
df.loc[df['month'] == 11, 'month_name'] = 'Nov'
df.loc[df['month'] == 12, 'month_name'] = 'Dec'

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mosquito_Indicator', data=df)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set_title('Mosquito distribution along the year of 2017')
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mosquito_Indicator', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)


plt.savefig('m2018_mosq.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='rain(mm)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('rain(mm)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2018_rain.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mean_T(℃)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mean_T(℃)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2018_temp.png')

# %%
plt.scatter(df['rain(mm)'],df['mosquito_Indicator'],color='red',marker='+')
plt.xlabel('rain(mm)', fontsize=20)
plt.ylabel('mosquito_Indicator', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.scatter(df['mean_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x="month_name", y="mean_T(℃)", 
            order=['Jan', 'Feb', 'March','April','May','June','July','August','Sept','Oct','Nov','Dec'],
            data=df)
plt.ylabel("mean_T(℃)", size=20)
plt.xlabel("Month", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
#plt.title("StackOverflow Survey Data", size=18)
plt.savefig("temp_2018_variation_monthly_boxplot.png")

# %%
gk = df.groupby('month_name')

# %%
gk.first()
# Out:
#                  date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  \
# month_name
# April        4/1/2018                10.0       0.0       15.6      11.7
# August       8/1/2018                81.0       0.0       33.6      27.8
# Dec         12/1/2018                 5.5       0.0        5.5       0.8
# Feb          2/1/2018                 5.5       0.0       -4.0      -8.8
# Jan          1/1/2018                 5.5       0.0       -1.3      -5.1
# July         7/1/2018               602.2      83.5       21.9      21.0
# June         6/1/2018               413.6       0.0       23.8      17.5
# March        3/1/2018                 5.5       0.5       -0.2      -4.3
# May          5/1/2018                24.0       0.0       20.4      17.8
# Nov         11/8/2018                 5.5      64.0       11.8      10.5
# Oct         10/1/2018               197.3       0.0       15.4      13.0
# Sept         9/1/2018               508.6       0.0       25.5      20.8
#
# ...

# %%
gk['mosquito_Indicator'].describe()
# Out:
#             count        mean         std    min      25%    50%       75%  \
# month_name
# April        30.0   21.803333   25.904340    0.5    1.600   18.1    24.825
# August       31.0  156.012903  131.110355   44.7   75.150   98.3   196.450
# Dec          31.0    5.500000    0.000000    5.5    5.500    5.5     5.500
# Feb          35.0    5.500000    0.000000    5.5    5.500    5.5     5.500
# Jan          32.0    5.500000    0.000000    5.5    5.500    5.5     5.500
# July         31.0  787.625806  204.890081  524.4  602.200  739.1  1000.000
# June         36.0  580.866667  174.355410  346.3  455.650  544.6   620.875
# March        34.0    5.500000    0.000000    5.5    5.500    5.5     5.500
# May          31.0  141.535484  131.845780   13.4   41.350   98.3   175.200
# Nov          15.0    5.500000    0.000000    5.5    5.500    5.5     5.500
# Oct          15.0  113.893333   65.167712   34.6   50.000  155.4   167.400
# ...

# %%
gk['mosquito_Indicator'].mean()
# Out:
# month_name
# April      21.803333
# August    156.012903
# Dec         5.500000
# Feb         5.500000
# Jan         5.500000
# July      787.625806
# June      580.866667
# March       5.500000
# May       141.535484
# Nov         5.500000
# Oct       113.893333
# Sept      524.756667
# Name: mosquito_Indicator, dtype: float64

# %%
gk['mean_T(℃)'].mean()
# Out:
# month_name
# April     12.986667
# August    28.761290
# Dec       -0.606452
# Feb       -0.937143
# Jan       -4.050000
# July      27.796774
# June      22.880556
# March      8.214706
# May       18.167742
# Nov        5.186667
# Oct       14.906667
# Sept      21.496667
# Name: mean_T(℃), dtype: float64

# %%
gk['rain(mm)'].mean()
# Out:
# month_name
# April     4.343333
# August    6.535484
# Dec       0.529032
# Feb       1.162857
# Jan       0.265625
# July      5.987097
# June      4.763889
# March     1.455882
# May       7.161290
# Nov       5.073333
# Oct       6.866667
# Sept      2.283333
# Name: rain(mm), dtype: float64

# %%
gk['mean_T(℃)'].describe()
# Out:
#             count       mean       std   min     25%    50%     75%   max
# month_name
# April        30.0  12.986667  4.216039   3.9  10.025  13.70  15.575  19.2
# August       31.0  28.761290  3.130674  22.7  26.100  29.90  30.850  33.7
# Dec          31.0  -0.606452  5.650365 -10.5  -4.900   0.00   3.000  11.5
# Feb          35.0  -0.937143  4.334953 -10.1  -3.500  -0.40   2.150   4.6
# Jan          32.0  -4.050000  5.586158 -14.8  -7.750  -3.60   0.450   4.7
# July         31.0  27.796774  3.265423  20.8  25.950  28.20  30.350  32.6
# June         36.0  22.880556  1.445549  20.2  21.900  22.55  23.725  27.1
# March        34.0   8.214706  4.283664  -0.7   5.050   7.95  10.700  17.0
# May          31.0  18.167742  2.816663  11.2  16.200  18.10  20.350  23.2
# Nov          15.0   5.186667  2.513071   1.9   3.100   5.00   6.400  11.8
# Oct          15.0  14.906667  2.870656   7.2  13.700  15.20  16.650  19.3
# ...

# %%
gk['rain(mm)'].describe()
# Out:
#             count      mean        std  min  25%  50%    75%   max
# month_name
# April        30.0  4.343333  11.407973  0.0  0.0  0.0  3.000  59.0
# August       31.0  6.535484  18.613768  0.0  0.0  0.0  4.000  96.5
# Dec          31.0  0.529032   1.901262  0.0  0.0  0.0  0.000   9.5
# Feb          35.0  1.162857   4.314278  0.0  0.0  0.0  0.000  25.0
# Jan          32.0  0.265625   0.770257  0.0  0.0  0.0  0.000   3.3
# July         31.0  5.987097  18.198951  0.0  0.0  0.0  0.300  83.5
# June         36.0  4.763889  13.511628  0.0  0.0  0.0  0.500  71.5
# March        34.0  1.455882   4.985384  0.0  0.0  0.0  0.375  27.0
# May          31.0  7.161290  17.530158  0.0  0.0  0.0  3.750  83.0
# Nov          15.0  5.073333  16.539497  0.0  0.0  0.0  0.100  64.0
# Oct          15.0  6.866667  16.531860  0.0  0.0  0.0  0.000  55.5
# Sept         30.0  2.283333   7.023806  0.0  0.0  0.0  0.425  34.5

# %%
plt.scatter(df['max_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.664

# %%
corr, _ = pearsonr(df['rain(mm)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.109

# %%
corr, _ = spearmanr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.836

# %%
corr, _ = spearmanr(df['rain(mm)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.142

# %% [markdown]
# # 2019

# %%
df = pd.read_csv('m2019.csv')
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)
# 0      1/1/2019                 5.5       0.0       -5.0      -8.2      -0.6
# 1      1/2/2019                 5.5       0.0       -4.9      -8.8       0.2
# 2      1/3/2019                 5.5       0.0       -3.5      -8.4       3.2
# 3      1/4/2019                 5.5       0.0       -1.1      -6.2       4.1
# 4      1/5/2019                 5.5       0.0       -2.8      -5.5       1.1
# ..          ...                 ...       ...        ...       ...       ...
# 353  12/27/2019                 5.5       0.0       -1.7      -4.6       2.6
# 354  12/28/2019                 5.5       0.0        1.1      -3.6       6.1
# 355  12/29/2019                 5.5       1.4        3.8       1.1       6.2
# 356  12/30/2019                 5.5       0.4        2.7      -5.7       6.8
# 357  12/31/2019                 5.5       0.0       -7.9     -10.9      -4.5
#
# [358 rows x 6 columns]

# %%
df['month_year'] = pd.to_datetime(df['date']).dt.to_period('M')
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2019                 5.5       0.0       -5.0      -8.2      -0.6
# 1  1/2/2019                 5.5       0.0       -4.9      -8.8       0.2
# 2  1/3/2019                 5.5       0.0       -3.5      -8.4       3.2
# 3  1/4/2019                 5.5       0.0       -1.1      -6.2       4.1
# 4  1/5/2019                 5.5       0.0       -2.8      -5.5       1.1
#
#   month_year
# 0    2019-01
# 1    2019-01
# 2    2019-01
# 3    2019-01
# 4    2019-01

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#        date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0  1/1/2019                 5.5       0.0       -5.0      -8.2      -0.6
# 1  1/2/2019                 5.5       0.0       -4.9      -8.8       0.2
# 2  1/3/2019                 5.5       0.0       -3.5      -8.4       3.2
# 3  1/4/2019                 5.5       0.0       -1.1      -6.2       4.1
# 4  1/5/2019                 5.5       0.0       -2.8      -5.5       1.1
#
#   month_year  month
# 0    2019-01      1
# 1    2019-01      1
# 2    2019-01      1
# 3    2019-01      1
# 4    2019-01      1

# %%
df['month_name'] = 'other'
df.loc[df['month'] == 1, 'month_name'] = 'Jan'
df.loc[df['month'] == 2, 'month_name'] = 'Feb'
df.loc[df['month'] == 3, 'month_name'] = 'March'
df.loc[df['month'] == 4, 'month_name'] = 'April'
df.loc[df['month'] == 5, 'month_name'] = 'May'
df.loc[df['month'] == 6, 'month_name'] = 'June'
df.loc[df['month'] == 7, 'month_name'] = 'July'
df.loc[df['month'] == 8, 'month_name'] = 'August'
df.loc[df['month'] == 9, 'month_name'] = 'Sept'
df.loc[df['month'] == 10, 'month_name'] = 'Oct'
df.loc[df['month'] == 11, 'month_name'] = 'Nov'
df.loc[df['month'] == 12, 'month_name'] = 'Dec'

# %%
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0      1/1/2019                 5.5       0.0       -5.0      -8.2      -0.6
# 1      1/2/2019                 5.5       0.0       -4.9      -8.8       0.2
# 2      1/3/2019                 5.5       0.0       -3.5      -8.4       3.2
# 3      1/4/2019                 5.5       0.0       -1.1      -6.2       4.1
# 4      1/5/2019                 5.5       0.0       -2.8      -5.5       1.1
# ..          ...                 ...       ...        ...       ...       ...
# 353  12/27/2019                 5.5       0.0       -1.7      -4.6       2.6
# 354  12/28/2019                 5.5       0.0        1.1      -3.6       6.1
# 355  12/29/2019                 5.5       1.4        3.8       1.1       6.2
# 356  12/30/2019                 5.5       0.4        2.7      -5.7       6.8
# 357  12/31/2019                 5.5       0.0       -7.9     -10.9      -4.5
#
#     month_year  month month_name
# ...

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mosquito_Indicator', data=df)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set_title('Mosquito distribution along the year of 2017')
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mosquito_Indicator', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)


plt.savefig('m2019_mosq.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='rain(mm)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('rain(mm)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2019_rain.png')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
g=sns.lineplot(x='date', y='mean_T(℃)', data=df)

sns.set()
#sns.set(font_scale=2)

g.xaxis.set_major_locator(ticker.MultipleLocator(31))
g.xaxis.set_major_formatter(ticker.ScalarFormatter())

g.set_xticklabels(['a','Jan','Feb','March','April','May', 'June', 'July', 'August',
                   'Sept', 'Oct', 'Nov', 'Dec'], fontsize = 20)


#g.set(xlabel='months', ylabel='rain(mm)', fontsize=16)
g.set_xlabel('months', fontsize = 20)
g.set_ylabel('mean_T(℃)', fontsize = 20)

g.set_yticklabels(g.get_yticks(), size = 20)
#g.set_title('Rain fall distribution along the year of 2017')

plt.savefig('m2019_temp.png')

# %%
corr, _ = spearmanr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.716

# %%
corr, _ = spearmanr(df['rain(mm)'], df['mosquito_Indicator'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.170

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.718

# %%
corr, _ = pearsonr(df['rain(mm)'], df['mosquito_Indicator'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.230

# %%
# Import required libraries
from scipy.stats import kendalltau

# %%
corr, _ = kendalltau(df['rain(mm)'], df['mosquito_Indicator'])
print('Kendall Rank correlation: %.5f' % corr)
# Out:
# Kendall Rank correlation: 0.13630

# %%
corr, _ = kendalltau(df['mean_T(℃)'], df['mosquito_Indicator'])
print('Kendall Rank correlation: %.5f' % corr)
# Out:
# Kendall Rank correlation: 0.56607

# %%
plt.scatter(df['mean_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')

# %%
df['date_new'] =  pd.to_datetime(df['date'],  infer_datetime_format=True)
df['date_redo'] =  pd.to_datetime(df['date_new'], format='%d%b%Y:%H:%M:%S.%f')
df['date_redo'] = df['date_redo'].astype('int64')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['date_redo'] = df['date_redo']/100000000000
df
# Out:
#            date  mosquito_Indicator  rain(mm)  mean_T(℃)  min_T(℃)  max_T(℃)  \
# 0      1/1/2019                 5.5       0.0       -5.0      -8.2      -0.6
# 1      1/2/2019                 5.5       0.0       -4.9      -8.8       0.2
# 2      1/3/2019                 5.5       0.0       -3.5      -8.4       3.2
# 3      1/4/2019                 5.5       0.0       -1.1      -6.2       4.1
# 4      1/5/2019                 5.5       0.0       -2.8      -5.5       1.1
# ..          ...                 ...       ...        ...       ...       ...
# 356  12/27/2019                 5.5       0.0       -1.7      -4.6       2.6
# 357  12/28/2019                 5.5       0.0        1.1      -3.6       6.1
# 358  12/29/2019                 5.5       1.4        3.8       1.1       6.2
# 359  12/30/2019                 5.5       0.4        2.7      -5.7       6.8
# 360  12/31/2019                 5.5       0.0       -7.9     -10.9      -4.5
#
# ...

# %%
X = df.drop(['mosquito_Indicator','date','date_new','month_year','month_name','date_redo','min_T(℃)','max_T(℃)','rain(mm)'], axis=1)
X
# Out:
#      mean_T(℃)  month
# 0         -5.0      1
# 1         -4.9      1
# 2         -3.5      1
# 3         -1.1      1
# 4         -2.8      1
# ..         ...    ...
# 356       -1.7     12
# 357        1.1     12
# 358        3.8     12
# 359        2.7     12
# 360       -7.9     12
#
# [361 rows x 2 columns]

# %%
X1=X.drop(['min_T(℃)','max_T(℃)'], axis=1)

# %%
X1=X1.drop(['rain(mm)'], axis=1)

# %%
y=df['mosquito_Indicator']

# %%
# splitting X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
# splitting X and y into training and testing sets
from sklearn.model_selection import train_test_split
X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size=0.4, random_state=1)

# %%
rf = RandomForestRegressor(n_estimators = 300, max_features = 'sqrt', max_depth = 3, random_state = 18).fit(X_train, y_train)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

prediction = rf.predict(X_test)
mse = mean_squared_error(y_test, prediction)
rmse = mse**.5
print(mse)
print(rmse)
# Out:
# 21970.76301459336
# 148.2253791177252

# %%
plt.scatter(df['rain(mm)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("rain(mm)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("rain_variation_mosquito2019.png")

# %%
plt.scatter(df['mean_T(℃)'],df['mosquito_Indicator'],color='red',marker='+')
plt.ylabel("mosquito_Indicator", size=20)
plt.xlabel("mean_T(℃)", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
plt.savefig("temp_variation_mosquito2019.png")

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x="month_name", y="mean_T(℃)", 
            order=['Jan', 'Feb', 'March','April','May','June','July','August','Sept','Oct','Nov','Dec'],
            data=df)
plt.ylabel("mean_T(℃)", size=20)
plt.xlabel("Month", size=20)
plt.xticks(fontsize=20, rotation=0)
plt.yticks(fontsize=20, rotation=0)
#plt.title("StackOverflow Survey Data", size=18)
plt.savefig("temp_2019_variation_monthly_boxplot.png")
